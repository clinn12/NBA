# %% [markdown]
# ---
# title: Pull Historical NBA Standings
# project: NBA Data Collection
# file_type: notebook
# status: active
# purpose: Refresh and validate the shared historical regular-season standings publication.
# usage: Run top to bottom when an interactive standings refresh is preferred over the command-line script.
# last_updated: 2026-08-15
# ---
#
# # Pull Historical NBA Standings
#
# ## Purpose
# Refresh Basketball Reference standings through the canonical Data Collection script while preserving raw source HTML.
#
# ## How to use
# Open this notebook from the Data Collection project and run cells from top to bottom. The published CSV and manifest are the outputs.

# %% [markdown]
# ### Purpose
# This notebook is a guided workbench for pulling NBA regular-season standings. The production logic lives in scripts/pull_historical_standings.py so the same behavior can be run from notebooks or the command line.
#
# Why it matters: non-playoff and lowest-win penalty reports depend on complete, validated standings data. Keeping the notebook thin prevents notebook/script drift while preserving an easy interactive entry point.

# %%
# Configuration is managed in configs/historical_results.json.
# Change source paths or request behavior there so notebook and script runs stay aligned.

# %% [markdown]
# ---

# %% [markdown]
# ### Import Libraries

# %%
# Bootstrap imports whether Jupyter starts at the project root or notebooks folder.
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))
from data_collection.historical_results import load_config
from scripts.pull_historical_standings import update_standings

# %% [markdown]
# ---

# %% [markdown]
# ### Create Functions to Scrape and Clean the Data

# %%
#Load pipeline configuration
config = load_config()

# %%
#Run the standings pull
standings_df = update_standings(config)

# %%
#The End
