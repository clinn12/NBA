# %% [markdown]
# # Web Scrapper to Pull NBA Standings from Basketball Reference

# %% [markdown]
# ### Year (NBA Season)

# %%
#Specify the year in which to pull data. For example, the 2019-2020 season should be specified as 2020
year = 2020

# %% [markdown]
# ### Import Libraries and Configure URL

# %%
#Import libraries
from urllib.request import urlopen
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import string

# %%
#URL
url = "https://www.basketball-reference.com/leagues/NBA_{}_standings.html".format(year)

#This is the HTML from the given URL
html = urlopen(url, timeout=10)
soup = BeautifulSoup(html)

# %% [markdown]
# ### Eastern Conference

# %%
#Use findALL() to get the column headers
soup.findAll('tr', limit=2)

#Use getText()to extract the text we need into a list
ec_headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]
ec_headers = ec_headers[0:8]
ec_headers
# Out:
# ['Eastern Conference', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS']

# %%
#Create rows
ec_rows = soup.findAll('tr')[2:17]
ec_standings = [[tr.getText() for tr in ec_rows[i].findAll(['th','td'])]
            for i in range(len(ec_rows))]

# %%
#Create dataframe
ec = pd.DataFrame(ec_standings, columns=ec_headers)

# %%
ec.columns = ['Team','W','L','WL_pct','GB','PPG','OPPG','SRS']
ec['Conference'] = 'Eastern'
ec['Rank'] = ec.index+1
ec['Playoff_Team'] = np.where(ec['Rank'] <=8, 1,0)
ec['Year'] = year
ec['GB'] = np.where(ec['GB']=='—', 0, ec['GB'])
ec['GB'] = np.where(ec['GB']=='-', 0, ec['GB'])

# %%
#Clean invalid characters
invalidchar = string.punctuation
ec['Team'] = ec.Team.str.strip(invalidchar)

# %% [markdown]
# ### Western Conference

# %%
#Use findALL() to get the column headers
soup.findAll('tr', limit=2)

#Use getText()to extract the text we need into a list
wc_headers = [th.getText() for th in soup.findAll('tr', limit=2)[0].findAll('th')]
wc_headers = wc_headers[23:31]
wc_headers
# Out:
# ['Western Conference', 'W', 'L', 'W/L%', 'GB', 'PS/G', 'PA/G', 'SRS']

# %%
#Create rows
wc_rows = soup.findAll('tr')[18:33]
wc_standings = [[tr.getText() for tr in wc_rows[i].findAll(['th','td'])]
            for i in range(len(wc_rows))]

# %%
#Create dataframe
wc = pd.DataFrame(wc_standings, columns=wc_headers)

# %%
wc.columns = ['Team','W','L','WL_pct','GB','PPG','OPPG','SRS']
wc['Conference'] = 'Western'
wc['Rank'] = wc.index+1
wc['Playoff_Team'] = np.where(wc['Rank'] <=8, 1,0)
wc['Year'] = year
wc['GB'] = np.where(wc['GB']=='—', 0, ec['GB'])
wc['GB'] = np.where(wc['GB']=='-', 0, ec['GB'])

# %%
#Clean invalid characters
wc['Team'] = wc.Team.str.strip(invalidchar)

# %%
ec
# Out:
#                    Team   W   L WL_pct    GB    PPG   OPPG    SRS Conference  \
# 0       Milwaukee Bucks  56  17   .767     0  118.7  108.6   9.41    Eastern
# 1       Toronto Raptors  53  19   .736   2.5  112.8  106.5   5.97    Eastern
# 2        Boston Celtics  48  24   .667   7.5  113.7  107.3   5.83    Eastern
# 3        Indiana Pacers  45  28   .616  11.0  109.4  107.5   1.63    Eastern
# 4            Miami Heat  44  29   .603  12.0  112.0  109.1   2.59    Eastern
# 5    Philadelphia 76ers  43  30   .589  13.0  110.7  108.4   2.25    Eastern
# 6         Brooklyn Nets  35  37   .486  20.5  111.8  112.3  -1.01    Eastern
# 7         Orlando Magic  33  40   .452  23.0  107.3  108.3  -0.93    Eastern
# 8     Charlotte Hornets  23  42   .354  29.0  102.9  109.6  -7.03    Eastern
# 9    Washington Wizards  25  47   .347  30.5  114.4  119.1  -5.24    Eastern
# 10        Chicago Bulls  22  43   .338  30.0  106.8  109.9  -4.00    Eastern
# 11      New York Knicks  21  45   .318  31.5  105.8  112.3  -6.72    Eastern
# 12      Detroit Pistons  20  46   .303  32.5  107.2  110.8  -4.38    Eastern
# 13        Atlanta Hawks  20  47   .299  33.0  111.8  119.7  -7.71    Eastern
# 14  Cleveland Cavaliers  19  46   .292  33.0  106.9  114.8  -7.77    Eastern
#
#     Rank  Playoff_Team  Year
# 0      1             1  2020
# 1      2             1  2020
# 2      3             1  2020
# 3      4             1  2020
# 4      5             1  2020
# 5      6             1  2020
# 6      7             1  2020
# 7      8             1  2020
# 8      9             0  2020
# 9     10             0  2020
# 10    11             0  2020
# 11    12             0  2020
# 12    13             0  2020
# 13    14             0  2020
# 14    15             0  2020

# %%
wc
# Out:
#                       Team   W   L WL_pct    GB    PPG   OPPG    SRS  \
# 0       Los Angeles Lakers  52  19   .732     0  113.4  107.6   6.28
# 1     Los Angeles Clippers  49  23   .681   2.5  116.3  109.9   6.66
# 2           Denver Nuggets  46  27   .630   7.5  111.3  109.2   2.35
# 3          Houston Rockets  44  28   .611  11.0  117.8  114.8   3.13
# 4    Oklahoma City Thunder  44  28   .611  12.0  110.4  108.4   2.33
# 5                Utah Jazz  44  28   .611  13.0  111.3  108.8   2.52
# 6         Dallas Mavericks  43  32   .573  20.5  117.0  112.1   4.87
# 7   Portland Trail Blazers  35  39   .473  23.0  115.0  116.1  -0.61
# 8        Memphis Grizzlies  34  39   .466  29.0  112.6  113.7  -0.91
# 9             Phoenix Suns  34  39   .466  30.5  113.6  113.4   0.56
# 10       San Antonio Spurs  32  39   .451  30.0  114.1  115.2  -0.65
# 11        Sacramento Kings  31  41   .431  31.5  110.1  112.1  -1.59
# 12    New Orleans Pelicans  30  42   .417  32.5  115.8  117.1  -0.55
# 13  Minnesota Timberwolves  19  45   .297  33.0  113.3  117.5  -4.02
# 14   Golden State Warriors  15  50   .231  33.0  106.3  115.0  -8.12
#
#    Conference  Rank  Playoff_Team  Year
# 0     Western     1             1  2020
# 1     Western     2             1  2020
# 2     Western     3             1  2020
# 3     Western     4             1  2020
# 4     Western     5             1  2020
# 5     Western     6             1  2020
# 6     Western     7             1  2020
# 7     Western     8             1  2020
# 8     Western     9             0  2020
# 9     Western    10             0  2020
# 10    Western    11             0  2020
# 11    Western    12             0  2020
# 12    Western    13             0  2020
# 13    Western    14             0  2020
# 14    Western    15             0  2020
